# %%
print("1. Import different required library")
import os
import pandas as pd
import numpy as np
import seaborn as sns
# Out:
# 1. Import different required library

# %%
os.getcwd()
# Out:
# '/content'

# %%
data= pd.read_csv('creditcard.csv')

# %%
print("2.  Check the version of the Library")
print(pd.__version__,"pandas")
print(np.__version__,"numpy")
# Out:
# 2.  Check the version of the Library
# 1.0.5 pandas
# 1.18.5 numpy

# %%
print('Go for different observation like Info, description')
data.info()
# Out:
# Go for different observation like Info, description
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158300 entries, 0 to 158299
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    158300 non-null  float64
#  1   V1      158300 non-null  float64
#  2   V2      158300 non-null  float64
#  3   V3      158300 non-null  float64
#  4   V4      158300 non-null  float64
#  5   V5      158299 non-null  float64
#  6   V6      158299 non-null  float64
#  7   V7      158299 non-null  float64
#  8   V8      158299 non-null  float64
#  9   V9      158299 non-null  float64
#  10  V10     158299 non-null  float64
#  11  V11     158299 non-null  float64
#  12  V12     158299 non-null  float64
#  13  V13     158299 non-null  float64
#  14  V14     158299 non-null  float64
#  15  V15     158299 non-null  float64
#  16  V16     158299 non-null  float64
#  17  V17     158299 non-null  float64
# ...

# %%
data.info
# Out:
# <bound method DataFrame.info of             Time        V1        V2  ...       V28  Amount  Class
# 0            0.0 -1.359807 -0.072781  ... -0.021053  149.62    '0'
# 1            0.0  1.191857  0.266151  ...  0.014724    2.69    '0'
# 2            1.0 -1.358354 -1.340163  ... -0.059752  378.66    '0'
# 3            1.0 -0.966272 -0.185226  ...  0.061458  123.50    '0'
# 4            2.0 -1.158233  0.877737  ...  0.215153   69.99    '0'
# ...          ...       ...       ...  ...       ...     ...    ...
# 158295  111118.0  2.103835  0.045477  ... -0.057124    1.00    '0'
# 158296  111119.0  2.104138  0.075424  ... -0.056236    1.00    '0'
# 158297  111119.0 -4.272875  4.607616  ...  1.222301    1.79    '0'
# 158298  111119.0  2.076089  0.004229  ... -0.070471    1.00    '0'
# 158299  111119.0  2.102976 -0.039375  ...       NaN     NaN    NaN
#
# [158300 rows x 31 columns]>

# %%
data.head(10)
# Out:
#    Time        V1        V2        V3  ...       V27       V28  Amount  Class
# 0   0.0 -1.359807 -0.072781  2.536347  ...  0.133558 -0.021053  149.62    '0'
# 1   0.0  1.191857  0.266151  0.166480  ... -0.008983  0.014724    2.69    '0'
# 2   1.0 -1.358354 -1.340163  1.773209  ... -0.055353 -0.059752  378.66    '0'
# 3   1.0 -0.966272 -0.185226  1.792993  ...  0.062723  0.061458  123.50    '0'
# 4   2.0 -1.158233  0.877737  1.548718  ...  0.219422  0.215153   69.99    '0'
# 5   2.0 -0.425966  0.960523  1.141109  ...  0.253844  0.081080    3.67    '0'
# 6   4.0  1.229658  0.141004  0.045371  ...  0.034507  0.005168    4.99    '0'
# 7   7.0 -0.644269  1.417964  1.074380  ... -1.206921 -1.085339   40.80    '0'
# 8   7.0 -0.894286  0.286157 -0.113192  ...  0.011747  0.142404   93.20    '0'
# 9   9.0 -0.338262  1.119593  1.044367  ...  0.246219  0.083076    3.68    '0'
#
# [10 rows x 31 columns]

# %%
data.tail(-10)
# Out:
#             Time        V1        V2  ...       V28  Amount  Class
# 10          10.0  1.449044 -1.176339  ...  0.016253    7.80    '0'
# 11          10.0  0.384978  0.616109  ... -0.054337    9.99    '0'
# 12          10.0  1.249999 -1.221637  ...  0.042422  121.50    '0'
# 13          11.0  1.069374  0.287722  ...  0.021293   27.50    '0'
# 14          12.0 -2.791855 -0.327771  ... -0.030154   58.80    '0'
# ...          ...       ...       ...  ...       ...     ...    ...
# 158295  111118.0  2.103835  0.045477  ... -0.057124    1.00    '0'
# 158296  111119.0  2.104138  0.075424  ... -0.056236    1.00    '0'
# 158297  111119.0 -4.272875  4.607616  ...  1.222301    1.79    '0'
# 158298  111119.0  2.076089  0.004229  ... -0.070471    1.00    '0'
# 158299  111119.0  2.102976 -0.039375  ...       NaN     NaN    NaN
#
# [158290 rows x 31 columns]

# %%
data.describe
# Out:
# <bound method NDFrame.describe of             Time        V1        V2  ...       V28  Amount  Class
# 0            0.0 -1.359807 -0.072781  ... -0.021053  149.62    '0'
# 1            0.0  1.191857  0.266151  ...  0.014724    2.69    '0'
# 2            1.0 -1.358354 -1.340163  ... -0.059752  378.66    '0'
# 3            1.0 -0.966272 -0.185226  ...  0.061458  123.50    '0'
# 4            2.0 -1.158233  0.877737  ...  0.215153   69.99    '0'
# ...          ...       ...       ...  ...       ...     ...    ...
# 158295  111118.0  2.103835  0.045477  ... -0.057124    1.00    '0'
# 158296  111119.0  2.104138  0.075424  ... -0.056236    1.00    '0'
# 158297  111119.0 -4.272875  4.607616  ...  1.222301    1.79    '0'
# 158298  111119.0  2.076089  0.004229  ... -0.070471    1.00    '0'
# 158299  111119.0  2.102976 -0.039375  ...       NaN     NaN    NaN
#
# [158300 rows x 31 columns]>

# %%
data.describe()
# Out:
#                 Time             V1  ...            V28         Amount
# count  158300.000000  158300.000000  ...  158299.000000  158299.000000
# mean    56688.818838      -0.219468  ...       0.002348      87.782007
# std     23919.790608       1.844038  ...       0.311090     245.632483
# min         0.000000     -56.407510  ...     -11.710896       0.000000
# 25%     39892.000000      -1.011166  ...      -0.014044       5.640000
# 50%     57890.500000      -0.247322  ...       0.022339      21.980000
# 75%     75190.250000       1.169674  ...       0.077980      77.500000
# max    111119.000000       2.439207  ...      33.847808   19656.530000
#
# [8 rows x 30 columns]

# %%
data.sample(10)
# Out:
#            Time        V1        V2        V3  ...       V27       V28  Amount  Class
# 94562   64942.0  1.427757 -1.304401  0.639095  ...  0.053447  0.007784   15.80    '0'
# 43095   41370.0 -0.859943  1.068105  2.117276  ...  0.053067  0.106858   11.39    '0'
# 45376   42312.0  1.181315 -0.418814  1.289448  ... -0.043023  0.017508   11.41    '0'
# 74308   55511.0 -2.047921 -0.353614  2.192464  ...  0.189602 -0.119925   29.60    '0'
# 101209  67759.0  1.159118  0.224563  0.409934  ...  0.041687  0.017360   11.46    '0'
# 63630   50807.0 -1.490492  1.748116  1.172497  ... -0.617952 -0.004902   36.72    '0'
# 20725   31233.0 -0.432280  0.915707  1.425967  ...  0.254523  0.105242    2.69    '0'
# 35535   38158.0 -0.589225  0.548308  1.447964  ... -0.023004 -0.083873   42.00    '0'
# 89997   62827.0 -3.017034 -2.229590  0.476622  ...  0.109503 -0.405033    1.00    '0'
# 144844  86437.0  1.803942  0.207644  0.361089  ...  0.012908 -0.039696   11.91    '0'
#
# [10 rows x 31 columns]

# %%
print('4. Check null Values')
# Out:
# 4. Check null Values

# %%
data.isnull().any()
# Out:
# Time      False
# V1        False
# V2        False
# V3        False
# V4        False
# V5         True
# V6         True
# V7         True
# V8         True
# V9         True
# V10        True
# V11        True
# V12        True
# V13        True
# V14        True
# V15        True
# V16        True
# V17        True
# V18        True
# V19        True
# V20        True
# V21        True
# V22        True
# V23        True
# V24        True
# V25        True
# V26        True
# V27        True
# V28        True
# Amount     True
# Class      True
# dtype: bool

# %%
print('5. Check duplicate values')
# Out:
# 5. Check duplicate values

# %%
data.duplicated
# Out:
# <bound method DataFrame.duplicated of             Time        V1        V2  ...       V28  Amount  Class
# 0            0.0 -1.359807 -0.072781  ... -0.021053  149.62    '0'
# 1            0.0  1.191857  0.266151  ...  0.014724    2.69    '0'
# 2            1.0 -1.358354 -1.340163  ... -0.059752  378.66    '0'
# 3            1.0 -0.966272 -0.185226  ...  0.061458  123.50    '0'
# 4            2.0 -1.158233  0.877737  ...  0.215153   69.99    '0'
# ...          ...       ...       ...  ...       ...     ...    ...
# 158295  111118.0  2.103835  0.045477  ... -0.057124    1.00    '0'
# 158296  111119.0  2.104138  0.075424  ... -0.056236    1.00    '0'
# 158297  111119.0 -4.272875  4.607616  ...  1.222301    1.79    '0'
# 158298  111119.0  2.076089  0.004229  ... -0.070471    1.00    '0'
# 158299  111119.0  2.102976 -0.039375  ...       NaN     NaN    NaN
#
# [158300 rows x 31 columns]>

# %%
data.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 158295    False
# 158296    False
# 158297    False
# 158298    False
# 158299    False
# Length: 158300, dtype: bool

# %%
print('6. Filter for different condition - come up with insights from the dataset, basic plot, distribution plots')
# Out:
# 6. Filter for different condition - come up with insights from the dataset, basic plot, distribution plots

# %%
data.sum(axis=1)
# Out:
# 0            152.701757
# 1              7.129726
# 2            380.751311
# 3            122.090404
# 4             77.368728
#               ...
# 158295    111122.716994
# 158296    111124.295604
# 158297    111131.801482
# 158298    111126.652330
# 158299    111119.942364
# Length: 158300, dtype: float64

# %%
print("7. Use a histogram to plot different columns")
data.sum(axis=0)
# Out:
# 7. Use a histogram to plot different columns
# Time      8.973840e+09
# V1       -3.474186e+04
# V2        8.067344e+03
# V3        9.274765e+04
# V4        2.214947e+04
# V5       -3.470377e+04
# V6        1.089300e+04
# V7       -1.580933e+04
# V8        6.969540e+03
# V9        2.575636e+03
# V10      -6.554055e+03
# V11       3.560404e+04
# V12      -1.696969e+04
# V13       1.223652e+04
# V14       1.534178e+04
# V15       2.481000e+04
# V16      -1.843220e+03
# V17       8.495268e+03
# V18      -9.079821e+03
# V19      -3.802503e+03
# V20       5.701428e+03
# V21      -6.001375e+03
# V22      -1.685524e+04
# V23      -4.231473e+03
# V24       1.369120e+03
# V25       1.711825e+04
# V26       2.648296e+03
# V27       2.253663e+02
# V28       3.716612e+02
# Amount    1.389580e+07
# dtype: float64

# %%
data.hist(bins=30, figsize=(15, 20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fb44f2fcfd0>,
# ...
#       dtype=object)

# %%
data.index
# Out:
# RangeIndex(start=0, stop=158300, step=1)

# %%
data.boxplot(column=['V1','V2','V3','V4','V5','V6','V7','V8','V9'],figsize=(20,15))

# %%
sns.distplot(data['V24'],bins=30,color='red') #In  this case we have taken V24 column.

# %%
data.plot(figsize=(20,15))

# %%
 data.groupby('V24').count().plot.bar()

# %%
data.hist(figsize=(15, 20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fb44dba4198>,
# ...
#       dtype=object)

# %%
data.plot.hist(bins=20,alpha=0.9,figsize=(15,10))
